# %% [markdown]
# # Phase 6 SP1 Validation
#
# This notebook runs Python-side relation checks and optional Rust/SP1 checks.

# %%
from pathlib import Path
import os
import runpy

candidates = [
    Path('scripts/experiments/kaggle_sp1_validation.py'),
    Path('/kaggle/working/zk_offline_dqn/scripts/experiments/kaggle_sp1_validation.py'),
    Path('kaggle_sp1_validation.py'),
]
for candidate in candidates:
    if candidate.exists():
        runpy.run_path(str(candidate), run_name='__main__')
        break
else:
    print('Could not find kaggle_sp1_validation.py. Upload the repo or set ZK_OFFLINE_DQN_REPO_URL.')

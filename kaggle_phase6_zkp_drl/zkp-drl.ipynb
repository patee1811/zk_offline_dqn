# %%
# !nproc
# !free -h
# !df -h
# !uname -a

# %%
# !sudo apt-get update
# !sudo apt-get install -y build-essential pkg-config libssl-dev protobuf-compiler libprotobuf-dev curl git clang lld

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install gymnasium numpy

# %%
# !curl https://sh.rustup.rs -sSf | sh -s -- -y

# %%
import os
home = os.environ['HOME']
os.environ['PATH'] = f"{home}/.cargo/bin:{os.environ['PATH']}"
os.environ['PROTOC'] = '/usr/bin/protoc'
os.environ['PROTOC_INCLUDE'] = '/usr/include'

# %%
# !rustc --version
# !cargo --version
# !protoc --version

# %%
# !curl -L https://sp1up.succinct.xyz | bash

# %%
import os
home = os.environ['HOME']
os.environ['PATH'] = f"{home}/.sp1/bin:{home}/.cargo/bin:{os.environ['PATH']}"

# %%
# !sp1up -v 6.1.0 || sp1up
# !cargo prove --version
# !cargo +succinct --version

# %%
# %cd /kaggle/working
# !rm -rf zk_offline_dqn
# !git clone -b cleanup-project-structure https://github.com/patee1811/zk_offline_dqn.git
# %cd /kaggle/working/zk_offline_dqn
# !git rev-parse --short HEAD
# !ls scripts/experiments/benchmark_mountaincar_forward_td_sp1.py

# %%
# %cd /kaggle/working/zk_offline_dqn
# !PYTHONPATH=. python3 scripts/experiments/benchmark_mountaincar_forward_td_sp1.py --skip-sp1

# %%
# %cd /kaggle/working/zk_offline_dqn
# !PYTHONPATH=. python3 scripts/experiments/benchmark_mountaincar_forward_td_sp1.py --prove

# %%
# %cd /kaggle/working/zk_offline_dqn
# !cat artifacts/benchmarks/second_env_mountaincar/summary.md
